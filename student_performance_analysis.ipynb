# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 

df = pd.read_csv(r"A:\Data analyst\Python projects\Student Performance\StudentsPerformance.csv")

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.info
# Out:
# <bound method DataFrame.info of      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df.duplicated().sum()
# Out:
# 0

# %%
Cat_col = df.select_dtypes(include='object').columns
print(Cat_col)
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course'],
#       dtype='object')

# %%
Cat_col_int = df.select_dtypes(include='int64').columns
print(Cat_col_int)
# Out:
# Index(['math score', 'reading score', 'writing score'], dtype='object')

# %%
print(df['gender'].unique())
# Out:
# ['female' 'male']

# %%
print(df['gender'].value_counts())
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,8))
# Create a count plot instead of a barplot - this automatically handles the counting
sns.countplot(x='gender', data=df, palette='Set2')
plt.show()

# Alternative approach using barplot with value_counts directly
# plt.figure(figsize=(10,8))
# gender_counts = df['gender'].value_counts().reset_index()
# sns.barplot(x='index', y='gender', data=gender_counts, palette='Set2')
# plt.show()
# Out:
# C:\Users\Shivam\AppData\Local\Temp\ipykernel_29988\2460604713.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='gender', data=df, palette='Set2')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

for col in Cat_col:
    plt.figure(figsize=(7, 4))
    sns.countplot(data=df, x=col, order=df[col].value_counts().index, palette='Set2')
    plt.title(f'Count of {col}')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\Shivam\AppData\Local\Temp\ipykernel_29988\1439356848.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, order=df[col].value_counts().index, palette='Set2')
# C:\Users\Shivam\AppData\Local\Temp\ipykernel_29988\1439356848.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, order=df[col].value_counts().index, palette='Set2')
# C:\Users\Shivam\AppData\Local\Temp\ipykernel_29988\1439356848.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
plt.figure(figsize=(10,8))
sns.histplot(df.corr(numeric_only=True),kde=True,bins=30,palette='Set2')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Flatten the correlation matrix and remove self-correlations (i.e., 1s on the diagonal)
corr_matrix = df.corr(numeric_only=True)
corr_values = corr_matrix.where(~np.eye(corr_matrix.shape[0],dtype=bool)).stack()

plt.figure(figsize=(10, 6))
sns.histplot(corr_values, kde=True, bins=30, color='skyblue')
plt.title('Distribution of Correlation Values (Excluding Diagonal)')
plt.xlabel('Correlation')
plt.ylabel('Frequency')
plt.show()

# %%
for col in Cat_col_int:
    plt.figure(figsize=(8, 4))
    sns.histplot(df[col], kde=True, bins=30, color='salmon')
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.tight_layout()
    plt.show()

    # Boxplot to check outliers
    plt.figure(figsize=(6, 1))
    sns.boxplot(x=df[col], color='lightgreen')
    plt.title(f'Boxplot of {col}')
    plt.tight_layout()
    plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(numeric_only=True),annot=True,cmap='coolwarm',linewidths=0.5)
plt.title('Correlation Heatmap of Numeric Features')
plt.show()

# %%
df['Average_score'] = df[['math score', 'reading score', 'writing score']].mean(axis=1)
def performance_lable(score):
    if score >= 90:
        return 'Very Good'
    elif score >= 70:
        return 'Good'
    else:
        return 'Poor'
df['Score_lable']=df['Average_score'].apply(performance_lable)
plt.figure(figsize=(10,8))
sns.countplot(x='Score_lable',data=df,hue='gender')
plt.show()

# %%
sns.countplot(data=df, x='Score_lable', hue='gender')
plt.show()

# %%
sns.set_theme(style="whitegrid")

# %%
df.to_csv('student_performance_final.csv', index=False)

# %%
# Ensure consistent styling
sns.set_theme(style="whitegrid")

# Step 1: Feature engineering – if not already done
df['average_score'] = df[['math score', 'reading score', 'writing score']].mean(axis=1)

# Step 2: Group by multiple categories
grouped_df = (
    df.groupby(['gender', 'test preparation course', 'parental level of education'])
      .agg(average_score=('average_score', 'mean'),
           count=('average_score', 'count'))
      .reset_index()
      .sort_values(by='average_score', ascending=False)
)

# Step 3: Filter to show only groups with at least 20 students
filtered_df = grouped_df[grouped_df['count'] >= 20]

# Step 4: Pivot table for easier visualization
pivot = filtered_df.pivot_table(index='parental level of education',
                                 columns=['gender', 'test preparation course'],
                                 values='average_score')

# Step 5: Plot heatmap
plt.figure(figsize=(12, 6))
sns.heatmap(pivot, annot=True, cmap="YlGnBu", linewidths=0.5)
plt.title('Average Student Score by Parental Education, Gender, and Prep Course')
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()
